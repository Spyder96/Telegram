days ago ema ( close,200 ) and latest max ( 30 , latest high ) <= 30 days ago max ( 200 , latest high ) and latest volume > latest sma ( volume,50 ) ) ) or ( {cash} ( 3 days ago close > 3 days ago ema ( close,200 ) and 4 days ago  close <= 4 days ago  ema ( close,200 ) and 3 days ago ema ( close,50 ) < 3 days ago ema ( close,200 ) and latest max ( 30 , latest high ) <= 30 days ago max ( 200 , latest high ) and latest volume > latest sma ( volume,50 ) ) ) or ( {cash} ( 2 days ago close > 2 days ago ema ( close,200 ) and 3 days ago  close <= 3 days ago  ema ( close,200 ) and 2 days ago ema ( close,50 ) < 2 days ago ema ( close,200 ) and latest max ( 30 , latest high ) <= 30 days ago max ( 200 , latest high ) and latest volume > latest sma ( volume,50 ) ) ) or ( {cash} ( 1 day ago close > 1 day ago ema ( close,200 ) and 2 day ago  close <= 2 day ago  ema ( close,200 ) and 1 day ago ema ( close,50 ) < 1 day ago ema ( close,200 ) and latest max ( 30 , latest high ) <= 30 days ago max ( 200 , latest high ) and latest volume > latest sma ( volume,50 ) ) ) or ( {cash} ( latest close > latest ema ( close,200 ) and 1 day ago  close <= 1 day ago  ema ( close,200 ) and latest ema ( close,50 ) < latest ema ( close,200 ) and latest max ( 30 , latest high ) <= 30 days ago max ( 200 , latest high ) and latest volume > latest sma ( volume,50 ) ) ) ) ) "

# %%
Charting_Link = "https://chartink.com/screener/" 
Charting_url = 'https://chartink.com/screener/process'

# %%
def GetDataFromChartink (payload):
    payload={'scan_clause': payload}
    with requests.Session() as s:
        r = s.get(Charting_Link)
        
        soup = BeautifulSoup (r.text, "html.parser")
        csrf = soup.select_one("[name='csrf-token']")['content']
        s.headers['x-csrf-token'] = csrf 
        r = s.post(Charting_url, data=payload)
        df = pd.DataFrame(r.json()['data'])
        return df

# %%
df = GetDataFromChartink(new_scan)

# %%
import requests 
from dotenv import load_dotenv
import os
load_dotenv()
TelegramBotCredential=os.environ.get('BOT_TOKEN')
ReceiverTelegramID = int(os.environ.get('MY_TELEGRAM_ID'))
def SendMessageToTelegram(Message):
    try:
        Url = "https://api.telegram.org/bot" + str(TelegramBotCredential) +  "/sendMessage?chat_id=" + str(ReceiverTelegramID)
        
        textdata ={ "text":Message}
        response = requests.request("POST",Url,params=textdata)
    except Exception as e:
        Message = str(e) + ": Exception occur in SendMessageToTelegram"
        print(Message)  
		
		
def SendTelegramFile(FileName):
    Documentfile={'document':open(FileName,'rb')}
    
    Fileurl = "https://api.telegram.org/bot" + str(TelegramBotCredential) +  "/sendDocument?chat_id=" + str(ReceiverTelegramID)
      
    response = requests.request("POST",Fileurl,files=Documentfile)

# %%
df = df.sort_values(by='per_chg', ascending=False )

# %%
fig, ax = plt.subplots(1, 1)
ax.axis('off')
ax.axis('tight')
table = ax.table(cellText=df.values, colLabels=df.columns, loc='center', fontsize=11, cellLoc='center')
table.auto_set_font_size(False)
table.set_fontsize(10)
# adjust the column widths to fit the largest text element in each column
table.auto_set_column_width(col=list(range(len(df.columns))))

for i in range(len(df)):
    row_height = 0.10
    table._cells[(i+1, 0)].set_height(row_height ) # add extra padding
    table._cells[(i+1, 1)].set_height(row_height ) # add extra padding
    table._cells[(i+1, 2)].set_height(row_height ) # add extra padding
    table._cells[(i+1, 3)].set_height(row_height ) # add extra padding
    table._cells[(i+1, 4)].set_height(row_height ) # add extra padding
    table._cells[(i+1, 5)].set_height(row_height ) # add extra padding
    table._cells[(i+1, 6)].set_height(row_height ) # add extra padding

# save the image to a file
plt.savefig('table.png', dpi=300, bbox_inches='tight')

# display the image
plt.show()

# %%
SendTelegramFile('table.png')
